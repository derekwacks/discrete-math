# %% [markdown]
# Problem 2, with problem 1 contained in the first cell.
# (Problem 1 Author: Matthew Roman, Problem 2 Author: Derek Wacks)

# %% [markdown]
# A study of the distribution of primes. The first cell is the entire project compiled together with a menu. The second cell generates primes up to a certain n using the Sieve of Eratosthenes scheme. The third cell computes the time required to generate primes up to different n's as determined by a hardcoded list of N's ranging from [100, 10000000]. The results are then returned as a list of times and a corresponding time vs N graph.

# %% [markdown]
# Complete code below

# %%
import time
import matplotlib.pyplot as plt
import math
import numpy as np
 
againBool = True
while againBool == True:
    #import arrays
    print("What would you like to do?")
    print()
    possible = [1, 2, 3]
    okay = False
    while okay == False :
        menuChoice = int(input("You may:\nRun the GCD code (enter 1)\nList the primes up to an integer of your choice (enter 2)\nFind all primes up to a few large hardcoded N's and see the runtimes (enter 3) "))                     
        if menuChoice in possible:
            okay = True
        else: 
            print()
            print("Please choose option 1, 2, or 3")

    #_______________________________________________
    # Problem 1: GCD
    # Written by Matthew Roman (smr2219)
    if menuChoice == 1:
        #Problem 1
        def gcd(a, b):
          if a<=0 or b<=0:
            raise Exception("Please ensure that inputs are greater than 0.")
          r = a%b 
          print ("Modulus calculation: " + str(a%b))
          print ("Does a%b equal zero? " + str(r==0))
          if r==0:
            print ("Then b is our GCD!")
            return b 
          else:
            print ("Time to recurse! Now, a = "+str(b)+", and b = "+str(r))
            return gcd(b,r)

        #Test cases
        print(gcd(4278,8602))
        print("")
        print(gcd(406,555))
        print("")
        print(gcd(244,354))
        print("")
        print(gcd(3000,9000))
        print("")
        print(gcd(40000,123456))
        print("")
        print(gcd(12345678,12345678910))
        print("")
        print(gcd(89345892349,10924983985))
        print("")
        print(gcd(7895232,63161856))       
    #_______________________________________________
    # Code that prints all primes up to a user specified integer 
    
    if menuChoice == 2:
        # user input n
        size = input("Enter n: ")
        sizeInt = int(size)
        #creates list of ints of size n
        listOfInts = [i for i in range(2,sizeInt+1)]

        #print(listOfInts)

        for i in listOfInts:
            #print(i)
            z = sizeInt//i
            #print(z)

            #print(i, " has ", z, " multiples in the list")
            """
            for j in listOfInts:
                for k in range(2,z+1):
                    listOfInts.remove(k*j)
                    """
            if z>1:
                for k in range(2,z+1):
                    #print("the ",k, " time")
                    #print("removing multiples of ", i)
                    if k*i in listOfInts:
                        listOfInts.remove(k*i)     

        print("New List of primes up to n")
        print(listOfInts)  

    if menuChoice == 3:

        # user input n
        #size = input("Enter n ")
        #nList = [10000]
        nList = [10,100,1000,10000,20000,30000]
        nListnp = np.array(nList)
        timeList = []
        #normalizedTimeList = []
        #list = [10,100,1000,10000,100000,1000000]

        for i in nList:
            sizeInt = i
            #creates list of ints of size n
            start = time.time()
            listOfInts = [i for i in range(2,sizeInt+1)] #list of all ints up to n 
            #print(listOfInts)
            for j in listOfInts:
                #print(i)
                z = sizeInt//j
               # print(z)

                #print(i, " has ", z, " multiples in the list")
                #print()
                """
                for j in listOfInts:
                    for k in range(2,z+1):
                        listOfInts.remove(k*j)
                        """
                if z>1:
                    for k in range(2,z+1):
                     #   print("removing multiples of ", i)
                        if (k*j) in listOfInts:
                            listOfInts.remove(k*j) # All remaining elements in listOfInts are prime    

            #print("New List of primes up to n")
            #print(listOfInts)
            end = time.time()
            #x = math.log(end-start)
            timeList.append(end-start)
            #print(listOfInts)
            #print("THERE ARE ", len(listOfInts), " PRIMES IN THE FIRST ", i, " NUMBERS")
            #print()
            #timeList.append(x)
            print(end-start)

        #maxVal = max(timeList)
        #for i in timeList:
        #    normalizedTimeList.append(i/maxVal)
        #plt.plot(nList,normalizedTimeList)
        x = np.array(timeList)

        plt.plot(nListnp, x)
        plt.xlabel('N')
        plt.ylabel('Time')
        plt.show()

    okayAgainChoice = False
    while okayAgainChoice == False:
        againChoice = str(input("Would you like to choose again? (y/n) "))  
        if againChoice == 'y':
            print()
            print("Cool! ")
            print()
            againBool = True
            okayAgainChoice = True
        if againChoice == 'n':
            print()
            print("Goodbye world. ")
            print()
            againBool = False
            okayAgainChoice = True
# Out:
# What would you like to do?
#
# You may:
# Run the GCD code (enter 1)
# List the primes up to an integer of your choice (enter 2)
# Find all primes up to a few large hardcoded N's and see the runtimes (enter 3) 0
#
# Please choose option 1, 2, or 3
# You may:
# Run the GCD code (enter 1)
# List the primes up to an integer of your choice (enter 2)
# Find all primes up to a few large hardcoded N's and see the runtimes (enter 3) 1
# Modulus calculation: 4278
# Does a%b equal zero? False
# Time to recurse! Now, a = 8602, and b = 4278
# Modulus calculation: 46
# Does a%b equal zero? False
# Time to recurse! Now, a = 4278, and b = 46
# Modulus calculation: 0
# Does a%b equal zero? True
# Then b is our GCD!
# 46
#
# Modulus calculation: 406
# Does a%b equal zero? False
# Time to recurse! Now, a = 555, and b = 406
# Modulus calculation: 149
# Does a%b equal zero? False
# Time to recurse! Now, a = 406, and b = 149
# Modulus calculation: 108
# Does a%b equal zero? False
# Time to recurse! Now, a = 149, and b = 108
# Modulus calculation: 41
# Does a%b equal zero? False
# Time to recurse! Now, a = 108, and b = 41
# Modulus calculation: 26
# Does a%b equal zero? False
# Time to recurse! Now, a = 41, and b = 26
# Modulus calculation: 15
# Does a%b equal zero? False
# Time to recurse! Now, a = 26, and b = 15
# Modulus calculation: 11
# Does a%b equal zero? False
# Time to recurse! Now, a = 15, and b = 11
# Modulus calculation: 4
# Does a%b equal zero? False
# Time to recurse! Now, a = 11, and b = 4
# Modulus calculation: 3
# Does a%b equal zero? False
# Time to recurse! Now, a = 4, and b = 3
# Modulus calculation: 1
# Does a%b equal zero? False
# Time to recurse! Now, a = 3, and b = 1
# Modulus calculation: 0
# Does a%b equal zero? True
# Then b is our GCD!
# 1
#
# Modulus calculation: 244
# Does a%b equal zero? False
# Time to recurse! Now, a = 354, and b = 244
# Modulus calculation: 110
# Does a%b equal zero? False
# Time to recurse! Now, a = 244, and b = 110
# Modulus calculation: 24
# Does a%b equal zero? False
# Time to recurse! Now, a = 110, and b = 24
# Modulus calculation: 14
# Does a%b equal zero? False
# Time to recurse! Now, a = 24, and b = 14
# Modulus calculation: 10
# Does a%b equal zero? False
# Time to recurse! Now, a = 14, and b = 10
# Modulus calculation: 4
# Does a%b equal zero? False
# Time to recurse! Now, a = 10, and b = 4
# Modulus calculation: 2
# Does a%b equal zero? False
# Time to recurse! Now, a = 4, and b = 2
# Modulus calculation: 0
# Does a%b equal zero? True
# Then b is our GCD!
# 2
#
# Modulus calculation: 3000
# Does a%b equal zero? False
# Time to recurse! Now, a = 9000, and b = 3000
# Modulus calculation: 0
# Does a%b equal zero? True
# Then b is our GCD!
# 3000
#
# Modulus calculation: 40000
# Does a%b equal zero? False
# Time to recurse! Now, a = 123456, and b = 40000
# Modulus calculation: 3456
# Does a%b equal zero? False
# Time to recurse! Now, a = 40000, and b = 3456
# Modulus calculation: 1984
# Does a%b equal zero? False
# Time to recurse! Now, a = 3456, and b = 1984
# Modulus calculation: 1472
# Does a%b equal zero? False
# Time to recurse! Now, a = 1984, and b = 1472
# Modulus calculation: 512
# Does a%b equal zero? False
# Time to recurse! Now, a = 1472, and b = 512
# Modulus calculation: 448
# Does a%b equal zero? False
# Time to recurse! Now, a = 512, and b = 448
# Modulus calculation: 64
# Does a%b equal zero? False
# Time to recurse! Now, a = 448, and b = 64
# Modulus calculation: 0
# Does a%b equal zero? True
# Then b is our GCD!
# 64
#
# Modulus calculation: 12345678
# Does a%b equal zero? False
# Time to recurse! Now, a = 12345678910, and b = 12345678
# Modulus calculation: 910
# Does a%b equal zero? False
# Time to recurse! Now, a = 12345678, and b = 910
# Modulus calculation: 618
# Does a%b equal zero? False
# Time to recurse! Now, a = 910, and b = 618
# Modulus calculation: 292
# Does a%b equal zero? False
# Time to recurse! Now, a = 618, and b = 292
# Modulus calculation: 34
# Does a%b equal zero? False
# Time to recurse! Now, a = 292, and b = 34
# Modulus calculation: 20
# Does a%b equal zero? False
# Time to recurse! Now, a = 34, and b = 20
# Modulus calculation: 14
# Does a%b equal zero? False
# Time to recurse! Now, a = 20, and b = 14
# Modulus calculation: 6
# Does a%b equal zero? False
# Time to recurse! Now, a = 14, and b = 6
# Modulus calculation: 2
# Does a%b equal zero? False
# Time to recurse! Now, a = 6, and b = 2
# Modulus calculation: 0
# Does a%b equal zero? True
# Then b is our GCD!
# 2
#
# Modulus calculation: 1946020469
# Does a%b equal zero? False
# Time to recurse! Now, a = 10924983985, and b = 1946020469
# Modulus calculation: 1194881640
# Does a%b equal zero? False
# Time to recurse! Now, a = 1946020469, and b = 1194881640
# Modulus calculation: 751138829
# Does a%b equal zero? False
# Time to recurse! Now, a = 1194881640, and b = 751138829
# Modulus calculation: 443742811
# Does a%b equal zero? False
# Time to recurse! Now, a = 751138829, and b = 443742811
# Modulus calculation: 307396018
# Does a%b equal zero? False
# Time to recurse! Now, a = 443742811, and b = 307396018
# Modulus calculation: 136346793
# Does a%b equal zero? False
# Time to recurse! Now, a = 307396018, and b = 136346793
# Modulus calculation: 34702432
# Does a%b equal zero? False
# Time to recurse! Now, a = 136346793, and b = 34702432
# Modulus calculation: 32239497
# Does a%b equal zero? False
# Time to recurse! Now, a = 34702432, and b = 32239497
# Modulus calculation: 2462935
# Does a%b equal zero? False
# Time to recurse! Now, a = 32239497, and b = 2462935
# Modulus calculation: 221342
# Does a%b equal zero? False
# Time to recurse! Now, a = 2462935, and b = 221342
# Modulus calculation: 28173
# Does a%b equal zero? False
# Time to recurse! Now, a = 221342, and b = 28173
# Modulus calculation: 24131
# Does a%b equal zero? False
# Time to recurse! Now, a = 28173, and b = 24131
# Modulus calculation: 4042
# Does a%b equal zero? False
# Time to recurse! Now, a = 24131, and b = 4042
# Modulus calculation: 3921
# Does a%b equal zero? False
# Time to recurse! Now, a = 4042, and b = 3921
# Modulus calculation: 121
# Does a%b equal zero? False
# Time to recurse! Now, a = 3921, and b = 121
# Modulus calculation: 49
# Does a%b equal zero? False
# Time to recurse! Now, a = 121, and b = 49
# Modulus calculation: 23
# Does a%b equal zero? False
# Time to recurse! Now, a = 49, and b = 23
# Modulus calculation: 3
# Does a%b equal zero? False
# Time to recurse! Now, a = 23, and b = 3
# Modulus calculation: 2
# Does a%b equal zero? False
# Time to recurse! Now, a = 3, and b = 2
# Modulus calculation: 1
# Does a%b equal zero? False
# Time to recurse! Now, a = 2, and b = 1
# Modulus calculation: 0
# Does a%b equal zero? True
# Then b is our GCD!
# 1
#
# Modulus calculation: 7895232
# Does a%b equal zero? False
# Time to recurse! Now, a = 63161856, and b = 7895232
# Modulus calculation: 0
# Does a%b equal zero? True
# Then b is our GCD!
# 7895232
# Would you like to choose again? (y/n) n
#
# Goodbye world.

# %% [markdown]
# Code that prints all primes up to a user specified integer

# %%
# user input n
size = input("Enter n: ")
sizeInt = int(size)
#creates list of ints of size n
listOfInts = [i for i in range(2,sizeInt+1)]

#print(listOfInts)

for i in listOfInts:
    #print(i)
    z = sizeInt//i
    #print(z)

    #print(i, " has ", z, " multiples in the list")
    """
    for j in listOfInts:
        for k in range(2,z+1):
            listOfInts.remove(k*j)
            """
    if z>1:
        for k in range(2,z+1):
            #print("the ",k, " time")
            #print("removing multiples of ", i)
            if k*i in listOfInts:
                listOfInts.remove(k*i)     
  
print("New List of primes up to n")
print(listOfInts)
# Out:
# Enter n: 10
# New List of primes up to n
# [2, 3, 5, 7]

# %% [markdown]
# Producing primes with timing

# %%
import time
import matplotlib.pyplot as plt
import math
import numpy as np

# user input n
#size = input("Enter n ")
#nList = [10000]
nList = [10,100,1000,10000,20000,30000]
nListnp = np.array(nList)
timeList = []
#normalizedTimeList = []
#list = [10,100,1000,10000,100000,1000000]

for i in nList:
    sizeInt = i
    #creates list of ints of size n
    start = time.time()
    listOfInts = [i for i in range(2,sizeInt+1)] #list of all ints up to n 
    #print(listOfInts)
    for j in listOfInts:
        #print(i)
        z = sizeInt//j
       # print(z)

        #print(i, " has ", z, " multiples in the list")
        #print()
        """
        for j in listOfInts:
            for k in range(2,z+1):
                listOfInts.remove(k*j)
                """
        if z>1:
            for k in range(2,z+1):
             #   print("removing multiples of ", i)
                if (k*j) in listOfInts:
                    listOfInts.remove(k*j) # All remaining elements in listOfInts are prime    
        
    #print("New List of primes up to n")
    #print(listOfInts)
    end = time.time()
    #x = math.log(end-start)
    timeList.append(end-start)
    #print(listOfInts)
    #print("THERE ARE ", len(listOfInts), " PRIMES IN THE FIRST ", i, " NUMBERS")
    #print()
    #timeList.append(x)
    print(end-start)

#maxVal = max(timeList)
#for i in timeList:
#    normalizedTimeList.append(i/maxVal)
#plt.plot(nList,normalizedTimeList)
x = np.array(timeList)

plt.plot(nListnp, x)
plt.xlabel('N')
plt.ylabel('Time')
plt.show()

# %% [markdown]
# Copy of code from above, tweaked for testing

# %%
import time
import matplotlib.pyplot as plt
import math
import numpy as np

# user input n
#size = input("Enter n ")
nList = [10,100,1000,10000,20000,100000]
nListnp = np.array(nList)
timeList = []
#normalizedTimeList = []
#list = [10,100,1000,10000,100000,1000000]

for i in nList:
    sizeInt = i
    #creates list of ints of size n
    start = time.time()
    listOfInts = [i for i in range(2,sizeInt+1)]
    #print(listOfInts)
    for i in listOfInts:
        #print(i)
        z = sizeInt//i
       # print(z)

        #print(i, " has ", z, " multiples in the list")
        #print()
        """
        for j in listOfInts:
            for k in range(2,z+1):
                listOfInts.remove(k*j)
                """
        if z>1:
            for k in range(2,z+1):
             #   print("the ",k, " time")
             #   print("removing multiples of ", i)
                if k*i in listOfInts:
                    listOfInts.remove(k*i)     

    #print("New List of primes up to n")
    #print(listOfInts)
    end = time.time()
    #x = math.log(end-start)
    timeList.append(end-start)
    
    #timeList.append(x)
    print(end-start)

#maxVal = max(timeList)
#for i in timeList:
#    normalizedTimeList.append(i/maxVal)
#plt.plot(nList,normalizedTimeList)
x = np.array(timeList)
plt.plot(nListnp, x)
plt.xlabel('N')
plt.ylabel('Time')
plt.show()

# %%
import time
import matplotlib.pyplot as plt
import math
import numpy as np
 
againBool = True
while againBool == True:
    #import arrays
    print("What would you like to do?")
    print()
    possible = [1, 2, 3]
    okay = False
    while okay == False :
        menuChoice = int(input("You may:\nRun the GCD code (enter 1)\nList the primes up to an integer of your choice (enter 2)\nFind all primes up to a few large hardcoded N's and see the runtimes (enter 3) "))                     
        if menuChoice in possible:
            okay = True
        else: 
            print()
            print("Please choose option 1, 2, or 3")

    #_______________________________________________
    # Problem 1: GCD
    # Written by Matthew Roman (smr2219)
    if menuChoice == 1:
        #Problem 1
        def gcd(a, b):
          if a<=0 or b<=0:
            raise Exception("Please ensure that inputs are greater than 0.")
          r = a%b 
          print ("Modulus calculation: " + str(a%b))
          print ("Does a%b equal zero? " + str(r==0))
          if r==0:
            print ("Then b is our GCD!")
            return b 
          else:
            print ("Time to recurse! Now, a = "+str(b)+", and b = "+str(r))
            return gcd(b,r)

        #Test cases
        print(gcd(4278,8602))
        print("")
        print(gcd(406,555))
        print("")
        print(gcd(244,354))
        print("")
        print(gcd(3000,9000))
        print("")
        print(gcd(40000,123456))
        print("")
        print(gcd(12345678,12345678910))
        print("")
        print(gcd(89345892349,10924983985))
        print("")
        print(gcd(7895232,63161856))       
    #_______________________________________________
    # Code that prints all primes up to a user specified integer 
    
    if menuChoice == 2:
        # user input n
        size = input("Enter n: ")
        sizeInt = int(size)
        #creates list of ints of size n
        listOfInts = [i for i in range(2,sizeInt+1)]

        #print(listOfInts)

        for i in listOfInts:
            #print(i)
            z = sizeInt//i
            #print(z)

            #print(i, " has ", z, " multiples in the list")
            """
            for j in listOfInts:
                for k in range(2,z+1):
                    listOfInts.remove(k*j)
                    """
            if z>1:
                for k in range(2,z+1):
                    #print("the ",k, " time")
                    #print("removing multiples of ", i)
                    if k*i in listOfInts:
                        listOfInts.remove(k*i)     

        print("New List of primes up to n")
        print(listOfInts)  

    if menuChoice == 3:

        # user input n
        #size = input("Enter n ")
        #nList = [10000]
        nList = [1,10,100,1000,10000,100000]
        #nList = [10,100,1000,10000,20000,30000]        
        nListnp = np.array(nList)
        timeList = []
        #normalizedTimeList = []
        #list = [10,100,1000,10000,100000,1000000]

        for i in nList:
            sizeInt = i
            #creates list of ints of size n
            start = time.time()
            listOfInts = [i for i in range(2,sizeInt+1)] #list of all ints up to n 
            #print(listOfInts)
            for j in listOfInts:
                #print(i)
                z = sizeInt//j
               # print(z)

                #print(i, " has ", z, " multiples in the list")
                #print()
                """
                for j in listOfInts:
                    for k in range(2,z+1):
                        listOfInts.remove(k*j)
                        """
                if z>1:
                    for k in range(2,z+1):
                     #   print("removing multiples of ", i)
                        if (k*j) in listOfInts:
                            listOfInts.remove(k*j) # All remaining elements in listOfInts are prime    

            #print("New List of primes up to n")
            #print(listOfInts)
            end = time.time()
            #x = math.log(end-start)
            timeList.append(end-start)
            #print(listOfInts)
            #print("THERE ARE ", len(listOfInts), " PRIMES IN THE FIRST ", i, " NUMBERS")
            #print()
            #timeList.append(x)
            print(end-start)

        #maxVal = max(timeList)
        #for i in timeList:
        #    normalizedTimeList.append(i/maxVal)
        #plt.plot(nList,normalizedTimeList)
        x = np.array(timeList)

        plt.plot(nListnp, x)
        plt.xlabel('N')
        plt.ylabel('Time')
        plt.show()

    okayAgainChoice = False
    while okayAgainChoice == False:
        againChoice = str(input("Would you like to choose again? (y/n) "))  
        if againChoice == 'y':
            print("Cool! ")
            print()
            againBool = True
            okayAgainChoice = True
        if againChoice == 'n':
            print("Goodbye world. ")
            againBool = False
            okayAgainChoice = True
# Out:
# What would you like to do?
#
# You may:
# Run the GCD code (enter 1)
# List the primes up to an integer of your choice (enter 2)
# Find all primes up to a few large hardcoded N's and see the runtimes (enter 3) 3
# 0.012818098068237305
# 1.52587890625e-05
# 0.00020694732666015625
# 0.008727073669433594
# 0.7514901161193848
# 80.34900712966919
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda/lib/python3.6/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     729             try:
# --> 730                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     731             except Exception:
#
# ~/anaconda/lib/python3.6/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     795         try:
# --> 796             msg_list = socket.recv_multipart(mode, copy=copy)
#     797         except zmq.ZMQError as e:
#
# ~/anaconda/lib/python3.6/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     394         """
# --> 395         parts = [self.recv(flags, copy=copy, track=track)]
#     396         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv (zmq/backend/cython/socket.c:7683)()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv (zmq/backend/cython/socket.c:7460)()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy (zmq/backend/cython/socket.c:2344)()
#
# ~/anaconda/lib/python3.6/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc (zmq/backend/cython/socket.c:9621)()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-64-84a9f15d5b3c> in <module>()
#     146     okayAgainChoice = False
#     147     while okayAgainChoice == False:
# --> 148         againChoice = str(input("Would you like to choose again? (y/n) "))
#     149         if againChoice == 'y':
#     150             print("Cool! ")
#
# ~/anaconda/lib/python3.6/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     703             self._parent_ident,
#     704             self._parent_header,
# --> 705             password=False,
#     706         )
#     707
#
# ~/anaconda/lib/python3.6/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     733             except KeyboardInterrupt:
#     734                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 735                 raise KeyboardInterrupt
#     736             else:
#     737                 break
#
# KeyboardInterrupt:
